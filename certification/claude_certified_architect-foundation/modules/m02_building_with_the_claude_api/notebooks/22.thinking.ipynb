# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv(override=True)

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget": thinking_budget
        }

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "")

chat(messages, thinking=True)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[4], line 5
#       1 messages = []
#       2
#       3 add_user_message(messages, "")
#       4
# ----> 5 chat(messages, thinking=True)
#
# Cell In[3], line 51, in chat(messages, system, stop_sequences, tools, thinking, thinking_budget)
#      47             "type": "enabled",
#      48             "budget": thinking_budget
#      49         }
#      50
# ---> 51     message = client.messages.create(**params)
#      52     return message
#
# File ~/Documents/Claude_Certified_Developer-Foundational/.venv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Documents/Claude_Certified_Developer-Foundational/.venv/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:980, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, thinking, tool_choice, tools, user_profile_id, workspace_id, extra_headers, extra_query, extra_body, timeout)
#     965     warnings.warn(
#     966         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     967         UserWarning,
#     968         stacklevel=3,
#     969     )
#     971 extra_headers = {
#     972     **strip_not_given(
#     973         {
#    (...)    978     **(extra_headers or {}),
#     979 }
# --> 980 return self._post(
#     981     "/v1/messages",
#     982     body=maybe_transform(
#     983         {
#     984             "max_tokens": max_tokens,
#     985             "messages": messages,
#     986             "model": model,
#     987             "cache_control": cache_control,
#     988             "container": container,
#     989             "inference_geo": inference_geo,
#     990             "metadata": metadata,
#     991             "output_config": output_config,
#     992             "service_tier": service_tier,
#     993             "stop_sequences": stop_sequences,
#     994             "stream": stream,
#     995             "system": system,
#     996             "thinking": thinking,
#     997             "tool_choice": tool_choice,
#     998             "tools": tools,
#     999         },
#    1000         message_create_params.MessageCreateParamsStreaming
#    1001         if stream
#    1002         else message_create_params.MessageCreateParamsNonStreaming,
#    1003     ),
#    1004     options=make_request_options(
#    1005         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1006     ),
#    1007     cast_to=Message,
#    1008     stream=stream or False,
#    1009     stream_cls=Stream[RawMessageStreamEvent],
#    1010 )
#
# File ~/Documents/Claude_Certified_Developer-Foundational/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1507, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1503     raise TypeError("Passing both `files` and `content` is not supported")
#    1504 opts = FinalRequestOptions.construct(
#    1505     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1506 )
# -> 1507 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Claude_Certified_Developer-Foundational/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1191, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1188     if not response.is_closed:
#    1189         response.read()
# -> 1191     raise self._make_status_error_from_response(response) from None
#    1193 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'thinking.enabled.budget_tokens: Field required'}, 'request_id': 'req_011Cf1fyG4UYunUaeczJsysd'}
